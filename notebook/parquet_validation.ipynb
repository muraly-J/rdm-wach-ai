# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_parquet("D:/AHU/rdm-wach-ai/data/raw/e0101.parquet")
df.head()
# Out:
#                        time  result     table  controller  site  \
# 0 2025-10-30 08:15:00+00:00     NaN  5.228070         NaN   NaN
# 1 2025-10-30 08:30:00+00:00     NaN  5.000000         NaN   NaN
# 2 2025-10-30 08:45:00+00:00     NaN  5.333333         NaN   NaN
# 3 2025-10-30 09:00:00+00:00     NaN  5.380952         NaN   NaN
# 4 2025-10-30 09:15:00+00:00     NaN  5.769231         NaN   NaN
#
#    digital_input_1_and_2  power_factor_avg  power_factor_l1  power_factor_l2  \
# 0                    0.0          0.777500         0.747500         0.757500
# 1                    0.0          0.776667         0.746667         0.756667
# 2                    0.0          0.776667         0.746667         0.756667
# 3                    0.0          0.766667         0.740000         0.736667
# 4                    0.0          0.760000         0.740000         0.730000
#
#    power_factor_l3  ...  power_l2  power_l3  power_total  energy_export  \
# ...

# %%
len(df)
# Out:
# 10047

# %%
df.columns
# Out:
# Index(['time', 'result', 'table', 'controller', 'site',
#        'digital_input_1_and_2', 'power_factor_avg', 'power_factor_l1',
#        'power_factor_l2', 'power_factor_l3', 'units', 'current_l1_thd',
#        'current_l3_thd', 'current_unbalance', 'volts_l1_thd', 'volts_l2_thd',
#        'volts_l3_thd', 'volts_unbalance', 'current_avg', 'current_l1',
#        'current_l2', 'current_l3', 'freq', 'volts_l1_l2', 'volts_l1_n',
#        'volts_l2_l3', 'volts_l2_n', 'volts_l3_l1', 'volts_l3_n',
#        'volts_l_l_avg', 'volts_l_n_avg', 'apparent_power_demand',
#        'apparent_power_l1', 'apparent_power_l2', 'apparent_power_l3',
#        'apparent_power_total', 'apparent_energy', 'reactive_power_demand',
#        'reactive_energy_export', 'reactive_energy_import', 'max_power_demand',
#        'power_demand', 'power_l1', 'power_l2', 'power_l3', 'power_total',
#        'energy_export', 'energy_import', 'reactive_power_l1',
# ...

# %%
#to see the merged data 
df = pd.read_parquet("D:/AHU/rdm-wach-ai/data/merged/ahu_all.parquet")
df.tail(60)
# Out:
#                            time  result     table  controller  site  \
# 30081 2026-02-11 09:00:00+00:00     NaN  5.153846         NaN   NaN
# 30082 2026-02-11 09:15:00+00:00     NaN  5.615385         NaN   NaN
# 30083 2026-02-11 09:30:00+00:00     NaN  5.292683         NaN   NaN
# 30084 2026-02-11 09:45:00+00:00     NaN  5.512195         NaN   NaN
# 30085 2026-02-11 10:00:00+00:00     NaN  5.421053         NaN   NaN
# 30086 2026-02-11 10:15:00+00:00     NaN  5.205128         NaN   NaN
# 30087 2026-02-11 10:30:00+00:00     NaN  5.302326         NaN   NaN
# 30088 2026-02-11 10:45:00+00:00     NaN  5.404762         NaN   NaN
# 30089 2026-02-11 11:00:00+00:00     NaN  4.785714         NaN   NaN
# 30090 2026-02-11 11:15:00+00:00     NaN  5.368421         NaN   NaN
# 30091 2026-02-11 11:30:00+00:00     NaN  5.390244         NaN   NaN
# 30092 2026-02-11 11:45:00+00:00     NaN  5.434783         NaN   NaN
# 30093 2026-02-11 12:00:00+00:00     NaN  5.372093         NaN   NaN
# ...
